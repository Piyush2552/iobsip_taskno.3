# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/car data.csv")

# %%
df.head()
# Out:
#    Unnamed: 0 Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  \
# 0           0     ritz  2014           3.35           5.59       27000
# 1           1      sx4  2013           4.75           9.54       43000
# 2           2     ciaz  2017           7.25           9.85        6900
# 3           3  wagon r  2011           2.85           4.15        5200
# 4           4    swift  2014           4.60           6.87       42450
#
#    Fuel_Type Seller_Type  Transmission  Owner
# 0          2      Dealer             1      0
# 1          1      Dealer             1      0
# 2          2      Dealer             1      0
# 3          2      Dealer             1      0
# 4          1      Dealer             1      0

# %%
df.tail()
# Out:
#      Unnamed: 0 Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  \
# 296         296     city  2016           9.50           11.6       33988
# 297         297     brio  2015           4.00            5.9       60000
# 298         298     city  2009           3.35           11.0       87934
# 299         299     city  2017          11.50           12.5        9000
# 300         300     brio  2016           5.30            5.9        5464
#
#      Fuel_Type Seller_Type  Transmission  Owner
# 296          1      Dealer             1      0
# 297          2      Dealer             1      0
# 298          2      Dealer             1      0
# 299          1      Dealer             1      0
# 300          2      Dealer             1      0

# %%
df.shape
# Out:
# (301, 10)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Car_Name', 'Year', 'Selling_Price', 'Present_Price',
#        'Kms_Driven', 'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     301 non-null    int64
#  1   Car_Name       301 non-null    object
#  2   Year           301 non-null    int64
#  3   Selling_Price  301 non-null    float64
#  4   Present_Price  301 non-null    float64
#  5   Kms_Driven     301 non-null    int64
#  6   Fuel_Type      301 non-null    int64
#  7   Seller_Type    301 non-null    object
#  8   Transmission   301 non-null    int64
#  9   Owner          301 non-null    int64
# dtypes: float64(2), int64(6), object(2)
# memory usage: 23.6+ KB

# %%
df.describe()
# Out:
#        Unnamed: 0         Year  Selling_Price  Present_Price     Kms_Driven  \
# count  301.000000   301.000000     301.000000     301.000000     301.000000
# mean   150.000000  2013.627907       4.661296       7.628472   36947.205980
# std     87.035433     2.891554       5.082812       8.644115   38886.883882
# min      0.000000  2003.000000       0.100000       0.320000     500.000000
# 25%     75.000000  2012.000000       0.900000       1.200000   15000.000000
# 50%    150.000000  2014.000000       3.600000       6.400000   32000.000000
# 75%    225.000000  2016.000000       6.000000       9.900000   48767.000000
# max    300.000000  2018.000000      35.000000      92.600000  500000.000000
#
#         Fuel_Type  Transmission       Owner
# count  301.000000    301.000000  301.000000
# mean     1.787375      0.867110    0.039867
# std      0.425801      0.340021    0.212302
# min      0.000000      0.000000    0.000000
# 25%      2.000000      1.000000    0.000000
# 50%      2.000000      1.000000    0.000000
# 75%      2.000000      1.000000    0.000000
# max      2.000000      1.000000    2.000000

# %% [markdown]
# null value treatment

# %%
df.isnull().sum()
# Out:
# Unnamed: 0       0
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
sns.countplot(data=df,x='Kms_Driven')
# Out:
# <AxesSubplot:xlabel='Kms_Driven', ylabel='count'>

# %%
sns.countplot(data=df,x='Owner')
# Out:
# <AxesSubplot:xlabel='Owner', ylabel='count'>

# %%
sns.countplot(data=df,x='Transmission')
# Out:
# <AxesSubplot:xlabel='Transmission', ylabel='count'>

# %%
sns.countplot(data=df, x='Fuel_Type')
# Out:
# <AxesSubplot:xlabel='Fuel_Type', ylabel='count'>

# %%
df['Transmission'].unique()
# Out:
# array([1, 0])

# %%
trans_mission=pd.get_dummies(df['Transmission'],drop_first=True)
print(trans_mission.head())
# Out:
#    1
# 0  1
# 1  1
# 2  1
# 3  1
# 4  1

# %%
df['Transmission'] = trans_mission

# %%
df['Fuel_Type'].unique()
# Out:
# array([2, 1, 0])

# %%
# importing LabelEncoder
from sklearn.preprocessing import LabelEncoder

# %%
encoder = LabelEncoder()

# %%
df['Fuel_Type']=encoder.fit_transform(df['Fuel_Type'])
# It returns:
# 0 -> CNG
# 1 -> Disel
# 2 -> LPG
# 3 -> Petrol

# %%
df['Owner'].unique()
# Out:
# array([0, 1, 2])

# %%
encoder = LabelEncoder()
df['Owner'] = encoder.fit_transform(df['Owner'])
# 0 -> First
# 1 -> Fourth & Above
# 2 -> Second
# 3 -> Third

# %%
df.head()
# Out:
#    Unnamed: 0 Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  \
# 0           0     ritz  2014           3.35           5.59       27000
# 1           1      sx4  2013           4.75           9.54       43000
# 2           2     ciaz  2017           7.25           9.85        6900
# 3           3  wagon r  2011           2.85           4.15        5200
# 4           4    swift  2014           4.60           6.87       42450
#
#    Fuel_Type Seller_Type  Transmission  Owner
# 0          2      Dealer             1      0
# 1          1      Dealer             1      0
# 2          2      Dealer             1      0
# 3          2      Dealer             1      0
# 4          1      Dealer             1      0

# %%
df.head()
# Out:
#    Unnamed: 0 Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  \
# 0           0     ritz  2014           3.35           5.59       27000
# 1           1      sx4  2013           4.75           9.54       43000
# 2           2     ciaz  2017           7.25           9.85        6900
# 3           3  wagon r  2011           2.85           4.15        5200
# 4           4    swift  2014           4.60           6.87       42450
#
#    Fuel_Type Seller_Type  Transmission  Owner
# 0          2      Dealer             1      0
# 1          1      Dealer             1      0
# 2          2      Dealer             1      0
# 3          2      Dealer             1      0
# 4          1      Dealer             1      0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     301 non-null    int64
#  1   Car_Name       301 non-null    object
#  2   Year           301 non-null    int64
#  3   Selling_Price  301 non-null    float64
#  4   Present_Price  301 non-null    float64
#  5   Kms_Driven     301 non-null    int64
#  6   Fuel_Type      301 non-null    int64
#  7   Seller_Type    301 non-null    object
#  8   Transmission   301 non-null    uint8
#  9   Owner          301 non-null    int64
# dtypes: float64(2), int64(5), object(2), uint8(1)
# memory usage: 21.6+ KB

# %%
sns.pairplot(df)

# %%
sns.boxplot(x='Fuel_Type',y='Kms_Driven',data=df)
# Out:
# <AxesSubplot:xlabel='Fuel_Type', ylabel='Kms_Driven'>

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Car_Name', 'Year', 'Selling_Price', 'Present_Price',
#        'Kms_Driven', 'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
predict = "Present_Price"
df = df[['Unnamed: 0', 'Car_Name', 'Year', 'Selling_Price', 'Present_Price',
       'Kms_Driven', 'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner']]

# %%
x = np.array(df.drop([predict], 1))
y = np.array(df[predict])
# Out:
# <ipython-input-100-7430aa0d1dd8>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   x = np.array(df.drop([predict], 1))

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2)

# %%
a=int(input("Year: "))
b=int(input("Kilometers_Driven: "))
c=int(input("Fuel_Type: "))
d=int(input("Transmission: "))
e=int(input("Owner_Type: "))
f=float(input("Mileage: "))
g=int(input("Engine: "))
h=float(input("Power: "))
i=float(input("Seats: "))

input_data=(a,b,c,d,e,f,g,h,i)
arr= np.asarray(input_data).reshape(1,-1)
prediction=model.predict(arr)
print("The value of car in lakhs should be approx Rs ",prediction)
